# %%
import quandl
quandl.ApiConfig.api_key = "KxKMd8dsHx1sWnaGj6_U"
import numpy as np
import matplotlib as plt
import pandas as pd
import keras
from sklearn.preprocessing import MinMaxScaler
# Out:
# /usr/bin/anaconda/envs/py35/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def get_monthly_close_prices(start_date,end_date):
    
    df = quandl.get_table('SHARADAR/SEP',date={'gte':start_date,'lte':end_date}, qopts={'columns':['ticker','date','close']},paginate=True).fillna(value=0)
    close = df.pivot(index='date', columns='ticker', values='close')
    monthly = close.resample('BM', how=lambda x: x[-1])
    #.agg(lambda x: x[-1])
    return monthly

# %%
monthly_prices = get_monthly_close_prices('2018-06-01','2019-01-01')
# Out:
# /usr/bin/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:5: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   """

# %%
def get_monthly_returns(monthly_prices):
    """
    Compute returns for each ticker and date in close.
    
    Parameters
    ----------
    close : DataFrame
        Close prices for each ticker and date
    
    Returns
    -------
    returns : DataFrame
        Returns for each ticker and date
    """
        

    #.agg(lambda x: x[-1])
    monthly_returns = (monthly_prices - monthly_prices.shift(1))/monthly_prices.shift(1).fillna(value=0)
    
    
    return monthly_returns

# %%
monthly_retuns_june_dec_18 = get_monthly_returns(monthly_prices)

# %%
monthly_retuns_june_dec_18.head()
# Out:
# ticker             A        AA       AAC     AAGIY       AAL     AALBF  \
# date
# 2018-06-29       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-07-31  0.067917 -0.077005  0.108858  0.003711  0.041623       NaN
# 2018-08-31  0.022714  0.032355 -0.147257 -0.019909  0.023773       NaN
# 2018-09-28  0.044418 -0.095590 -0.138826  0.033082  0.020998 -0.055386
# 2018-10-31 -0.081514 -0.133911 -0.277851 -0.152528 -0.151222  0.000000
#
# ticker          AAMC      AAME       AAN      AAOI    ...         ZSAN  \
# date                                                  ...
# 2018-06-29       NaN       NaN       NaN       NaN    ...          NaN
# 2018-07-31 -0.060215 -0.037037 -0.003222 -0.144098    ...     0.024510
# 2018-08-31 -0.053394  0.057692  0.148003  0.076243    ...    -0.002392
# 2018-09-28 -0.035455 -0.090909  0.095334 -0.403772    ...    -0.019185
# 2018-10-31 -0.181287  0.120000 -0.134594 -0.203974    ...    -0.171149
#
# ticker           ZTO       ZTS      ZUMZ       ZUO     ZURVY  ZX      ZYME  \
# date
# 2018-06-29       NaN       NaN       NaN       NaN       NaN NaN       NaN
# 2018-07-31 -0.008500  0.015143 -0.095808 -0.098162  0.039634 NaN -0.161705
# 2018-08-31 -0.069087  0.047641  0.375276  0.124338 -0.008472 NaN  0.133979
# 2018-09-28 -0.102384  0.010596 -0.154093 -0.162074  0.034834 NaN  0.117438
# 2018-10-31 -0.021123 -0.015400 -0.117268 -0.116400 -0.016196 NaN -0.186624
#
# ticker          ZYNE      ZYXI
# date
# 2018-06-29       NaN       NaN
# 2018-07-31 -0.317248 -0.035484
# 2018-08-31  0.207519  0.030100
# 2018-09-28  0.016189 -0.032468
# 2018-10-31 -0.355392  0.030201
#
# [5 rows x 6788 columns]

# %%
monthly_retuns_june_dec_18 = monthly_retuns_june_dec_18.iloc[ 1: , : ]

# %%
monthly_retuns_june_dec_18 = monthly_retuns_june_dec_18.fillna(0)

# %%
#training_returns = monthly_retuns_june_dec_18.iloc[ :5 , : ]

# %%
#target_returns = monthly_retuns_june_dec_18.iloc[ 5:6 , : ]

# %%
def get_factor_data(start_date,end_date):
    
    df = quandl.get_table('SHARADAR/SF1',dimension='ARQ',calendardate={'gte':start_date, 'lte':end_date}, paginate=True).fillna(value=0)

    
    return df

# %%
#quandl.get_table('SHARADAR/SF1',dimension='ARY',calendardate={'gte':'2018-06-01', 'lte':'2019-01-01'}, paginate=True)

# %%
factors_10years = get_factor_data('2009-12-31','2019-01-01')

# %%
factors_10years.head
# Out:
# <bound method NDFrame.head of        ticker dimension calendardate    datekey reportperiod lastupdated  \
# None
# 0          ZZ       ARQ   2012-03-31 2012-03-27   2012-02-26  2018-05-16
# 1          ZZ       ARQ   2011-12-31 2012-01-18   2011-11-27  2018-05-16
# 2          ZZ       ARQ   2011-09-30 2011-09-27   2011-08-28  2018-05-16
# 3          ZZ       ARQ   2011-06-30 2011-06-28   2011-05-29  2018-05-16
# 4          ZZ       ARQ   2011-03-31 2011-03-29   2011-02-27  2018-05-16
# 5          ZZ       ARQ   2010-12-31 2011-01-21   2010-11-28  2018-05-16
# 6          ZZ       ARQ   2010-09-30 2010-09-30   2010-08-29  2018-05-16
# 7          ZZ       ARQ   2010-06-30 2010-06-29   2010-05-30  2018-05-16
# 8          ZZ       ARQ   2010-03-31 2010-03-31   2010-02-28  2018-05-16
# 9          ZZ       ARQ   2009-12-31 2010-01-25   2009-11-29  2018-05-16
# 10       ZYXI       ARQ   2018-12-31 2019-02-26   2018-12-31  2019-02-26
# 11       ZYXI       ARQ   2018-09-30 2018-11-06   2018-09-30  2019-02-26
# 12       ZYXI       ARQ   2018-06-30 2018-08-02   2018-06-30  2019-02-26
# 13       ZYXI       ARQ   2018-03-31 2018-05-08   2018-03-31  2019-02-26
# 14       ZYXI       ARQ   2017-12-31 2018-02-28   2017-12-31  2019-02-26
# 15       ZYXI       ARQ   2017-09-30 2017-11-13   2017-09-30  2019-02-26
# 16       ZYXI       ARQ   2017-06-30 2017-08-14   2017-06-30  2019-02-26
# 17       ZYXI       ARQ   2017-03-31 2017-05-26   2017-03-31  2019-02-26
# 18       ZYXI       ARQ   2016-12-31 2017-04-18   2016-12-31  2019-02-26
# 19       ZYXI       ARQ   2016-12-31 2017-04-17   2016-12-31  2019-02-26
# 20       ZYXI       ARQ   2016-09-30 2016-11-14   2016-09-30  2019-02-26
# 21       ZYXI       ARQ   2016-06-30 2016-08-23   2016-06-30  2019-02-26
# 22       ZYXI       ARQ   2016-03-31 2016-05-20   2016-03-31  2019-02-26
# 23       ZYXI       ARQ   2015-12-31 2016-03-31   2015-12-31  2019-02-26
# 24       ZYXI       ARQ   2015-09-30 2015-11-17   2015-09-30  2019-02-26
# 25       ZYXI       ARQ   2015-06-30 2015-08-14   2015-06-30  2019-02-26
# 26       ZYXI       ARQ   2015-03-31 2015-05-12   2015-03-31  2019-02-26
# 27       ZYXI       ARQ   2014-12-31 2015-03-31   2014-12-31  2019-02-26
# 28       ZYXI       ARQ   2014-09-30 2014-11-07   2014-09-30  2019-02-26
# 29       ZYXI       ARQ   2014-06-30 2014-10-10   2014-06-30  2019-02-26
# ...       ...       ...          ...        ...          ...         ...
# 177879      A       ARQ   2017-03-31 2017-06-06   2017-04-30  2019-03-05
# 177887         0.0    8000000.0             0.0  13.638    2.690000e+09
# 177888         0.0   11000000.0             0.0  13.714    2.726000e+09
# 177889         0.0   62000000.0             0.0  21.817    3.798000e+09
# 177890         0.0   37000000.0             0.0  19.790    3.255000e+09
# 177891         0.0   47000000.0             0.0  21.423    3.658000e+09
# 177892         0.0   -4000000.0             0.0  20.306    3.524000e+09
# 177893         0.0   43000000.0             0.0  20.250    3.381000e+09
# 177894         0.0   44000000.0             0.0  18.696    3.034000e+09
# 177895         0.0   32000000.0             0.0  19.090    2.910000e+09
# 177896         0.0   16000000.0             0.0  18.769    2.866000e+09
# 177897         0.0 -169000000.0             0.0  18.463    2.736000e+09
# 177898         0.0   -5000000.0             0.0  16.443    2.121000e+09
# 177899         0.0   38000000.0             0.0  21.328    4.175000e+09
# 177900         0.0   26000000.0             0.0  20.365    4.010000e+09
# 177901         0.0    4000000.0             0.0  20.349    3.732000e+09
# 177902         0.0  -49000000.0             0.0  19.284    3.718000e+09
# 177903         0.0   60000000.0             0.0  19.023    3.504000e+09
# 177904         0.0    5000000.0             0.0  17.663    3.192000e+09
# 177905         0.0  -49000000.0             0.0  22.517    3.086000e+09
# 177906         0.0   22000000.0             0.0  20.715    2.818000e+09
# 177907         0.0   31000000.0             0.0  20.106    3.003000e+09
# 177908         0.0    4000000.0             0.0  19.451    2.970000e+09
#
# [177909 rows x 111 columns]>

# %%
factors_june_dec_18['calendardate'].drop_duplicates().sort_values()

# %%
factors_june_dec_18.shape

# %%
import keras.losses
import tensorflow as tf

# Create loss function
def sign_penalty(y_true, y_pred):
    penalty = 100.
    loss = tf.where(tf.less(y_true * y_pred, 0), \
                     penalty * tf.square(y_true - y_pred), \
                     tf.square(y_true - y_pred))

    return tf.reduce_mean(loss, axis=-1)

keras.losses.sign_penalty = sign_penalty  # enable use of loss with keras
print(keras.losses.sign_penalty)

# %%
corr_matrix = df.corr().abs()

# %%
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper

# %%
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
factors_june_dec_18_reduced = factors_june_dec_18.drop(factors_june_dec_18[to_drop], axis=1)

# %%
factors_june_dec_18_reduced[factors_june_dec_18_reduced['calendardate'] != '2018-12-31']

# %%
factors_june_dec_18[factors_june_dec_18['calendardate'] != '2018-12-31']

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
factors_june_dec_18['calendardate'] != '2018-12-31'

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
factors_june_dec_18_reduced['calendardate']

# %%
features = factors_june_dec_18_reduced
target = monthly_retuns_june_dec_18

# %%
features.rename(columns={"calendardate": "date"})

# %%
from sklearn.preprocessing import scale

# Remove unimportant features (weekdays)
train_features = train_features.iloc[:, :-4]
test_features = test_features.iloc[:, :-4]

# Standardize the train and test features
scaled_train_features = scale(train_features)
scaled_test_features = scale(test_features)

# Plot histograms of the 14-day SMA RSI before and after scaling
f, ax = plt.subplots(nrows=2, ncols=1)
train_features.iloc[:, 2].hist(ax=ax[0])
ax[1].hist(scaled_train_features[:, 2])
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Dense

# Create the model
model_1 = Sequential()
model_1.add(Dense(100, input_dim=scaled_train_features.shape[1], activation='relu'))
model_1.add(Dense(20, activation='relu'))
model_1.add(Dense(1, activation='linear'))

# Fit the model
model_1.compile(optimizer='adam', loss='mse')
history = model_1.fit(scaled_train_features, train_targets, epochs=25)
